# %%
import tableauserverclient as TSC
import pandas as pd
import os
import datetime


print(os.environ.get('http_proxy'))
print(os.environ.get('HTTP_PROXY'))

os.environ['http_proxy'] = ""
os.environ['HTTP_PROXY'] = ""
os.environ['https_proxy'] = ""
os.environ['HTTPS_PROXY'] = ""
print(os.environ.get('http_proxy'))
print(os.environ.get('HTTP_PROXY'))


# Get Site name

site_name=[]
tableau_auth = TSC.TableauAuth('da-datamgmt', 'CJD48')
server = TSC.Server('http://tableau.cjd.th', use_server_version=True)
server.auth.sign_in(tableau_auth)

all_sites, pagination_item = server.sites.get()

for site in all_sites:
    site_name.append(site.content_url.replace(' ',''))
    
# Remove Default site 
#site_name=site_name[1:]


server.auth.sign_out()
# Out:
# None
# None

# %%
### sign in

relationship_df = pd.DataFrame(columns=['Site_Name','Project_Name','Dashboard_Name', 'Workbook_Name', 'Description', 'Connection_Type', 'Database_Connection', 'Datasource_Name', 'Table_Name','Owner', 'hasExtracts', 'extractLastRefreshTime', 'extractLastIncrementalUpdateTime', 'extractLastUpdateTime'])


for site in site_name:
    
    if site == "":
        temp_site = "Default"
    else:
        temp_site = site
    print(temp_site)

    tableau_auth = TSC.TableauAuth('da-datamgmt', 'CJD48', site)
    

    server = TSC.Server('http://tableau.cjd.th', use_server_version=True)
    server.auth.sign_in(tableau_auth)

# to filter a query (filter: {name: "dwd_cf_lcm_t_application_i_d"})

    query = """
    {
      workbooks {
          name 
          projectName
          upstreamDatabases {
              name 
              connectionType     
          }
          upstreamDatasources {
            name
            hasExtracts
            extractLastRefreshTime
            extractLastIncrementalUpdateTime
            extractLastUpdateTime 
            upstreamTables{
              name
            }
          }
          description
          owner{
              name
              username
              email
          }
          views{
              name
          }   
          
      }
    }"""
  
    resp = server.metadata.query(query)
    List_Data = resp['data']['workbooks']
   
    for dict in List_Data:
        wbName = dict['name']
        wbProject = dict['projectName']
      
        wbOwner = dict['owner']['username']
        desc = dict['description']
        for view in dict['views']:
            wbView = view['name']
        for datasource in dict['upstreamDatabases']:
            dbCon = datasource['name']
            connectionType = datasource['connectionType']
        for datasourceName in dict['upstreamDatasources']:
            dsName = datasourceName['name']
            hasExtracts = datasourceName['hasExtracts']
            extractLastRefreshTime = datasourceName['extractLastRefreshTime']
            extractLastIncrementalUpdateTime = datasourceName['extractLastIncrementalUpdateTime']
            extractLastUpdateTime = datasourceName['extractLastUpdateTime']
            
            
            for table in datasourceName['upstreamTables']:
                tbName = table['name']
                relationship_df = relationship_df.append({'Site_Name': temp_site,'Project_Name':wbProject,'Dashboard_Name':wbView,
                                                          'Workbook_Name': wbName, 'Description': desc, 'Connection_Type': connectionType, 
                                                          'Database_Connection': dbCon, 'Datasource_Name': dsName, 'Table_Name': tbName, 'Owner': wbOwner,
                                                          'hasExtracts':hasExtracts,'extractLastRefreshTime':extractLastRefreshTime,'extractLastIncrementalUpdateTime':extractLastIncrementalUpdateTime,
                                                           'extractLastUpdateTime':extractLastUpdateTime }, ignore_index=True)
# Out:
# Default
# financeandaccounting
# DataAnalyticDepartment
# DolfinWallet
# MarketingDepartment
# ConsumerFinanceDepartment
# MerchantDepartment
# ProductDepartment
# StrategyDepartment
# ComplianceDepartment
# OperationDepartment
# ITDepartment
# FraudDepartment
# DolfinExplorer

# %%
group_site_table = relationship_df.groupby(['Site_Name', 'Datasource_Name', 'Table_Name'])

count_site_table = group_site_table['Table_Name'].count()
group_table = count_site_table.groupby(['Site_Name', 'Datasource_Name','Table_Name'])
chk_dup_table = group_table.count()

duplicates = chk_dup_table[chk_dup_table > 1].index.tolist()

def chk_dup_fn(row):
    if row['Table_Name'] in duplicates:
        return "Y"
    return "N"

relationship_df['Flag_Duplicate'] = relationship_df.apply(lambda row: chk_dup_fn(row), axis=1)
relationship_df.drop_duplicates()
relationship_df=relationship_df.reset_index(drop=True)
relationship_df.loc[:,'extractLastRefreshTime'] = pd.to_datetime(relationship_df['extractLastRefreshTime'],utc=True).dt.tz_convert('Asia/Bangkok').dt.tz_localize(None)
relationship_df.loc[:,'extractLastIncrementalUpdateTime'] = pd.to_datetime(relationship_df['extractLastIncrementalUpdateTime'],utc=True).dt.tz_convert('Asia/Bangkok').dt.tz_localize(None)
relationship_df.loc[:,'extractLastUpdateTime'] = pd.to_datetime(relationship_df['extractLastUpdateTime'],utc=True).dt.tz_convert('Asia/Bangkok').dt.tz_localize(None)

relationship_df.to_excel("wb_datasources_refresh.xlsx", encoding='utf-8', index=False)

# %%
relationship_df
# Out:
#                 Site_Name            Project_Name             Dashboard_Name  \
# 0    financeandaccounting              PRODUCTION                Sheet 1 (2)
# 1    financeandaccounting             OUT OF DATE  Merchant Organic Expenses
# 2    financeandaccounting              PRODUCTION             ENDING_BALANCE
# 3    financeandaccounting              PRODUCTION             ENDING_BALANCE
# 4    financeandaccounting              PRODUCTION             ENDING_BALANCE
# ..                    ...                     ...                        ...
# 460        DolfinExplorer                MERCHANT     Total Tran by Merchant
# 461        DolfinExplorer                MERCHANT     Total Tran by Merchant
# 462        DolfinExplorer  FINANCE AND ACCOUNTING                cohort_test
# 463        DolfinExplorer  FINANCE AND ACCOUNTING                cohort_test
# 464        DolfinExplorer  FINANCE AND ACCOUNTING                    Sheet 9
#
# ...
